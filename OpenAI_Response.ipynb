# %%
from openai import OpenAI
client = OpenAI()

response = client.responses.create(
    model="gpt-5.4",
    input="Write a short bedtime story about a unicorn."
)

print(response.output_text)
# Out:
# Once upon a time, in a silver meadow at the edge of a sleepy forest, there lived a little unicorn named Moonbeam. Her coat shimmered like soft starlight, and her tiny horn glowed whenever she felt happy.
#
# Each night, Moonbeam loved to watch the sky fill with stars. But one evening, she noticed a small star flickering brighter and brighter, as if it were calling to her.
#
# Curious, Moonbeam followed the glow through the meadow, over a sparkling brook, and up a gentle hill. At the very top, she found not a fallen star, but a tiny firefly caught in a spider’s silky web.
#
# “Oh, don’t worry,” whispered Moonbeam kindly. With the lightest touch of her horn, she loosened the threads and set the firefly free.
#
# The grateful firefly circled around her happily, shining like a golden lantern. Soon, more fireflies appeared, twinkling all around Moonbeam until the whole hill glowed like a piece of the night sky.
#
# Moonbeam smiled, lay down in the soft grass, and watched her new glowing friends dance above her. The breeze hummed a gentle lullaby, the stars winked down, and before long, the little unicorn drifted into the sweetest dreams.
#
# And from that night on, whenever Moonbeam looked up at the stars, she remembered that even the smallest light can make the night feel magical.
#
# The end.

# %%
response  = client.responses.create(
    model="gpt-5.4", 
    input= "what in this image ?" "https://i.natgeofe.com/k/42e832f5-fd48-43ff-b338-091bdf4048ca/india-tajmahal_16x9.jpg?w=1200"
    
)

print(response.output_text)
# Out:
# It appears to be the Taj Mahal in India — the white marble mausoleum with its large central dome, minarets, and reflecting pool in front.
#
# If you want, I can also describe the scene in more detail.
